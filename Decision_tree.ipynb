# %% [markdown]
# <a href="https://colab.research.google.com/github/Lasisi-Samson/NULASS-MACHINE-LEARNING-/blob/main/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import library

# %%
import pandas as pd
# !pip install pyreadstat
import pyreadstat
from scipy.stats import ttest_ind

# %% [markdown]
# Load and assign data

# %%
Y_Train=pd.read_spss("y_train.sav")
X_Train=pd.read_spss("x_train.sav")
X_Test=pd.read_spss("x_test.sav")
Y_Test=pd.read_spss("y_test.sav")

# %% [markdown]
# Applying Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_Train = sc.fit_transform(X_Train)
X_Test = sc.fit_transform(X_Test)

# %% [markdown]
# Training the DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_Train, Y_Train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Predicting the Y_test

# %%
y_pred=model.predict(X_Test)
print(y_pred)
print(Y_Test)
# Out:
# ['Yes' 'Yes' 'Yes' 'Yes' 'No']
#   Will_buy
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
